# %%
library(tidyverse)
library(reshape2)
library(ggplot2)
library(RColorBrewer)
# library(networkD3)

library(tidytree)
library(treeio)
library(ggtree)
library(ggnewscale)
library(ggtreeExtra)
library(patchwork)
library(aplot)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# If you use the ggtree package suite in published research, please
# cite the appropriate paper(s):
#
# S Xu, Z Dai, P Guo, X Fu, S Liu, L Zhou, W Tang, T Feng, M Chen, L
# Zhan, T Wu, E Hu, Y Jiang, X Bo, G Yu. ggtreeExtra: Compact
# visualization of richly annotated phylogenetic data. Molecular Biology
# and Evolution. 2021, 38(9):4039-4042. doi: 10.1093/molbev/msab166
#
# Guangchuang Yu. Using ggtree to visualize data on tree-like structures.
# Current Protocols in Bioinformatics. 2020, 69:e96. doi:10.1002/cpbi.96
#
#
#
# Attaching package: ‘tidytree’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# treeio v1.26.0 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# LG Wang, TTY Lam, S Xu, Z Dai, L Zhou, T Feng, P Guo, CW Dunn, BR
# Jones, T Bradley, H Zhu, Y Guan, Y Jiang, G Yu. treeio: an R package
# for phylogenetic tree input and output with richly annotated and
# associated data. Molecular Biology and Evolution. 2020, 37(2):599-603.
# doi: 10.1093/molbev/msz240
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# Ecology and Evolution. 2017, 8(1):28-36. doi:10.1111/2041-210X.12628
#
# Guangchuang Yu. Using ggtree to visualize data on tree-like structures.
# Current Protocols in Bioinformatics. 2020, 69:e96. doi:10.1002/cpbi.96
#
#
#
# Attaching package: ‘treeio’
#
#
# The following object is masked from ‘package:tidytree’:
#
#     getNodeNum
#
#
# ggtree v3.10.1 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# Ecology and Evolution. 2017, 8(1):28-36. doi:10.1111/2041-210X.12628
#
# LG Wang, TTY Lam, S Xu, Z Dai, L Zhou, T Feng, P Guo, CW Dunn, BR
# Jones, T Bradley, H Zhu, Y Guan, Y Jiang, G Yu. treeio: an R package
# for phylogenetic tree input and output with richly annotated and
# associated data. Molecular Biology and Evolution. 2020, 37(2):599-603.
# doi: 10.1093/molbev/msz240
#
# Guangchuang Yu. Using ggtree to visualize data on tree-like structures.
# Current Protocols in Bioinformatics. 2020, 69:e96. doi:10.1002/cpbi.96
#
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# ggtreeExtra v1.12.0 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# S Xu, Z Dai, P Guo, X Fu, S Liu, L Zhou, W Tang, T Feng, M Chen, L
# Zhan, T Wu, E Hu, Y Jiang, X Bo, G Yu. ggtreeExtra: Compact
# visualization of richly annotated phylogenetic data. Molecular Biology
# and Evolution. 2021, 38(9):4039-4042. doi: 10.1093/molbev/msab166

# %% [markdown]
# # Loading Tree file with Taxonomy,Rank and RED decoration
# * Parse by ETEtookit in ete_parsetree.ipynb

# %%
single_arc_node=read.table("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/MEERv21_d95_gtdbr220_ar53_monophylogetic_RED.tsv",header = T,sep="\t")
single_bac_node=read.table("//dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/MEERv21_d95_gtdbr220_bac120_monophylogetic_RED.tsv",header=T,sep="\t")
#ggsave("Figures/F2B_Archcaea_RED_Distribution_0514.pdf",single_arc_distribute,width = 5,height = 4)

# %%
single_bac_node %>% group_by(rank) %>% count() %>% left_join(single_arc_node %>% group_by(rank) %>% count() ,by="rank") -> bibar_data
colnames(bibar_data) <-c("rank",'bacteria','archaea')
bibar_data$rank <- factor(c("Class","Family","Genus","Order","Phylum"),levels = rev(c("Phylum","Class","Order","Family","Genus")))
bibar_data[is.na(bibar_data)]<-0

# %%
bibar_data <- bibar_data %>% filter(rank!="Genus")

# %%
ggplot(bibar_data,aes(x=rank,fill=rank))+geom_bar(aes(y=-sqrt(bacteria)),stat = "identity")+theme_classic()+
  theme(axis.line = element_blank(),axis.title.y = element_blank(),axis.text.y = element_text(size = 12),legend.position = "None",axis.ticks.y=element_blank())+
  ylab("Bacteria")+scale_x_discrete(position = "top")
# Out:
# plot without title

# %%
rank_color=setNames(c("#E63946","#ffa200","#0087cb","#24a8ac","#98DF8A"),c("Phylum","Class","Order","Family","Genus"))
bac_newtaxon <- ggplot(bibar_data,aes(x=rank,fill=rank))+geom_bar(aes(y=-bacteria),stat = "identity")+theme_classic()+
  theme(axis.line = element_blank(),axis.title.y = element_blank(),axis.text.y = element_text(size = 12),legend.position = "None",axis.ticks.y=element_blank())+
  ylab("Bacteria")+scale_x_discrete(position = "top")+scale_fill_manual(values = rank_color)+coord_flip()
  

arc_newtaxon <- ggplot(bibar_data,aes(x=rank,fill=rank))+geom_bar(aes(y=archaea),stat = "identity")+theme_classic()+
  theme(axis.line = element_blank(),axis.title.y = element_blank(),axis.ticks.y=element_blank(),
        axis.text.y = element_blank(),legend.position = "None")+scale_fill_manual(values = rank_color)+
  #scale_y_continuous(breaks = c(0,55,110),limits = c(0,110))+
  ylab("Archaea")+
  coord_flip()

newtaxon_bar <- (bac_newtaxon|arc_newtaxon)+plot_layout(widths = c(2, 1))#+plot_annotation(caption="Data were transformed with square root.",theme=theme(plot.caption = element_text(size = 16,hjust = 0.5))) -> newtaxon_bar

# %%
ggsave("Fig2B-1_20240531.pdf",newtaxon_bar,width = 12,height = 5)

# %%
head(single_arc_node)

# %%
single_arc_node %>% filter(rank %in% c('class','order'))
# Out:
#   Leaf_Names             RED   rank
# 1 FDZ062-GYBk8-10.bin.89 0.549 class
# 2 FDZ033-GG0-2.bin.1143  0.512 order
# 3 FDZ066-BawG0-2.bin.493 0.599 order

# %%
single_arc_node %>% mutate(rank=factor(str_to_title(rank),levels=c("Phylum","Class","Order","Family","Genus"))) %>% 
    ggplot()+geom_histogram(aes(x=RED,fill=rank),binwidth=.025)+theme_classic()+ggtitle("Archaea Monophyletic Clade RED Distribution")+
    scale_fill_manual(values =  rank_color,name='Rank')+theme(legend.position="none",plot.title=element_text(hjust=.5)) ->single_arc_distribute

# %%
single_bac_node  %>% mutate(rank=factor(str_to_title(rank),levels=c("Phylum","Class","Order","Family","Genus"))) %>% 
    ggplot()+geom_histogram(aes(x=RED,fill=rank),binwidth=.025)+theme_classic()+ggtitle("Bacteria Monophyletic Clade RED Distribution")+
    scale_fill_manual(values =rank_color,name='Rank')+ theme(plot.title=element_text(hjust=.5)) ->single_bac_distribute

# %%
single_bac_distribute +single_arc_distribute +plot_layout(guide = 'collect') ->RED_distribute

# %%
RED_distribute
# Out:
# plot without title

# %%
ggsave("Figures/TREE_Monophyletic_RED_histogram_20240531.pdf",RED_distribute,width = 12,height = 5)

# %%
#Loading Tree file with Taxonomy,Rank and RED decoration

#ggsave("Figures/F2B_Bacteria_RED_Distribution_0514.pdf",single_bac_distribute,width = 5,height = 4) ## Figure 2B

# %%
arc_newtaxon+theme(axis.text.y = element_text(size = 12))+geom_text(aes(label = archaea,y=archaea),position=position_stack(vjust = 1),size=5,color="#252525")->arc_newtaxon_2
bac_newtaxon+geom_text(aes(label = bacteria,y=-bacteria),position=position_stack(vjust = 0),size=5,color="#252525")->bac_newtaxon_2
ggsave("./Archaea_newtaxons_count.pdf",arc_newtaxon_2,width = 8,height = 7)
ggsave("./Bacteria_newtaxons_count.pdf",bac_newtaxon_2,width = 8,height = 7)

# %%
bac_decorate_tree <- read.tree("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/bin_ca_score50_user_bactree_r220/gtdbtk.decorated.tree") #MMCv2.1 SGB trees
arc_decorate_tree <- read.tree("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/bin_ca_score50_user_arctree_r220/gtdbtk.decorated.tree") #MMCv2.1 SGB trees
bac_ggtree <- ggtree(bac_decorate_tree, layout="fan")
arc_ggtree <- ggtree(arc_decorate_tree,layout="fan")
bac_treedata <- bac_ggtree$data
bac_treedata$label <- gsub("\'","",bac_treedata$label)
arc_treedata <- arc_ggtree$data
arc_treedata$label <- gsub("\'","",arc_treedata$label)

tmp_tree_arc <- arc_treedata
tmp_tree_arc$node <- arc_treedata$node+nrow(bac_treedata)
tmp_tree_arc$parent <- arc_treedata$parent+nrow(bac_treedata)
tmp_tree_arc$y <- tmp_tree_arc$y+max(bac_treedata$y)
arc_root <-tmp_tree_arc %>% filter(label=="d__Archaea") %>% pull(node)
tmp_tree_arc[which(tmp_tree_arc$node==arc_root),"x"]<- 0.5

tmp_tree_all <- bac_treedata %>% bind_rows(tmp_tree_arc)
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.

# %%
tmp_tree_all$label

# %%
determine_node <- function(x,tree_tbl){
    if(grepl(",",x)){
        split=unlist(strsplit(x,","))
        return(MRCA(tree_tbl,split,use.names = T))
    }else{
        a=tree_tbl[tree_tbl$label ==x,]
        return(a)
    }
}

# %%
#single_arc_node$Leaf_Names |> map_df(\(x) MRCA(tmp_tree_all,unlist(strsplit(x,","),use.names = T)))

monophyletic_archaea <- read.table("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/MEERv21_ar53_monophylogetic.list",header=FALSE)$V1
monophyletic_bacteria <- read.table("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/MEERv21_bac120_monophylogetic.list",header=FALSE)$V1

# %%
monophyletic_archaea |>map_df(\(x) determine_node(x,tmp_tree_all)) -> arc_monophylogenetic_groups

# %%
monophyletic_bacteria |>map_df(\(x) determine_node(x,tmp_tree_all)) -> bac_monophylogenetic_groups

# %%
mono_node=bind_rows(arc_monophylogenetic_groups,bac_monophylogenetic_groups)$node

# %%
length(mono_node)
# Out:
# [1] 2372

# %%
tmp_tree_all_2 <- groupClade(tmp_tree_all,mono_node) 
tmp_tree_all_2$group <- as.character(tmp_tree_all_2$group)
tmp_tree_all_2$group[which(tmp_tree_all_2$group!=0)] <- "Novel"
tmp_tree_all_2$group[which(tmp_tree_all_2$group==0)] <- "Known"
tmp_tree_all_2$group <- factor(tmp_tree_all_2$group,levels = c('Novel','Known'))
#tmp_tree_all_2$label <- gsub("\'","",tmp_tree_all_2$label)

# %%
parent_phylum<- unique(tmp_tree_all_2 %>% filter(grepl("p__",label)) %>% pull(node))
lc_phylum <- data.frame(parent_phylum,as.numeric(map(parent_phylum,function(x) {
  if (x >nrow(bac_treedata)) {return(length(offspring(arc_decorate_tree,x-nrow(bac_treedata),tiponly=T)))} # the size of bacterial MMC tree
  else {return(length(offspring(bac_decorate_tree,x,tiponly=T)))}
})))
colnames(lc_phylum)[2] <- "leaves_count"
lc_phylum <- arrange(lc_phylum,desc(leaves_count))
top10<- as.data.frame(tmp_tree_all_2 %>% filter(node %in% lc_phylum$parent_phylum[1:10]) %>% pull(node,label))
top10$name <- gsub("\'","",rownames(top10))
#top10$name <- gsub ("1.0:p__","",top10$name)
top10$name <- gsub ("[0-9.]+:p__","",top10$name)
top10$name <- gsub("; c__.*","",top10$name)
colnames(top10)[1] <- "node"
# Out:
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".
#
# The "tiponly = TRUE" can be replaced by type="tips".

# %%
top10
# Out:
#                                       node  name
# 1.0:p__Patescibacteria                 6821 Patescibacteria
# 0.993:p__Chloroflexota                 8024 Chloroflexota
# 1.0:p__Planctomycetota                 9519 Planctomycetota
# 1.0:p__Omnitrophota                   10813 Omnitrophota
# 1.0:p__Marinisomatota                 11006 Marinisomatota
# 1.0:p__Bacteroidota                   11188 Bacteroidota
# 1.0:p__Zixibacteria; c__MSB-5A5       11598 Zixibacteria
# 0.99:p__Hydrogenedentota              11917 Hydrogenedentota
# 1.0:p__Pseudomonadota                 12362 Pseudomonadota
# 1.0:p__Nanoarchaeota; c__Nanoarchaeia 14384 Nanoarchaeota

# %%
lc_phylum[1:10,]
# Out:
#    parent_phylum leaves_count
# 1   8024         1342
# 2   9519         1153
# 3   6821         1143
# 4  12362         1032
# 5  14384          643
# 6  11188          358
# 7  11006          181
# 8  11598          160
# 9  11917          146
# 10 10813          136

# %%
top10 <- top10[match(lc_phylum$parent_phylum[1:10],top10$node),] %>% mutate(SGB_count=lc_phylum$leaves_count[1:10])

# %%
tree_summary <- read.table("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/12.re-classification/release_220/bin_ca_score50_tetra/MEERv21_gtdbr220_taxonomy.tsv",sep="\t",header=T,row.name=1)
tree_summary<-tree_summary %>% rownames_to_column(var = 'SGB')
# tree_summary$Phylum[which(!tree_summary$Phylum %in% top10$name)] <- 'Others'
# tree_summary$Phylum <- factor(tree_summary$Phylum,levels = append(top10$name,'Others'))

# %%
tree_anno <- tree_summary %>% select(SGB,Phylum)
tree_anno$Phylum[which(!tree_anno$Phylum %in% top10$name)] <- 'Others'
tree_anno$Phylum <- factor(tree_anno$Phylum,levels = append(top10$name,'Others'))

# %%
tree_summary %>% head()
# Out:
#   SGB                     Kingdom Phylum        Class        Order
# 1 FDZ053-RBk20-22.bin.385 Archaea Nanoarchaeota Nanoarchaeia Pacearchaeales
# 2 FDZ076-RGWu4-6.bin.298  Archaea Nanoarchaeota Nanoarchaeia Woesearchaeales
# 3 FDZ072-GBeBe12-14.bin.7 Archaea Nanoarchaeota Nanoarchaeia Pacearchaeales
# 4 FDZ070-GBeBe8-10.bin.5  Archaea Nanoarchaeota Nanoarchaeia Pacearchaeales
# 5 FDZ070-WuWY6-8.bin.299  Archaea Nanoarchaeota Nanoarchaeia Pacearchaeales
# 6 FDZ061-WW8-10.bin.116   Archaea Nanoarchaeota Nanoarchaeia Woesearchaeales
#   Family     Genus      Species
# 1 GW2011-AR1 JAGVXH01
# 2 JAGVZT01
# 3 GW2011-AR1
# 4 GW2011-AR1 BS150m-G67
# 5 GW2011-AR1
# 6 UBA10216

# %%
quality <- read_csv("/dssg/home/acct-trench/trench/Revision/01.AllBins/drep95/drep_all_95_greedy/data_tables/genomeInfo.csv")
# Out:
# Rows: 314378 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): genome
# dbl (4): completeness, contamination, length, N50
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
quality$genome=gsub(".fa","",quality$genome)

# %%
quality %>% head
# Out:
#   genome                 completeness contamination length  N50
# 1 FDZ076-YW-C2-4.bin.100 20.04        0.000              NA   NA
# 2 FDZ076-YW-C2-4.bin.101 56.10        6.184         1977715 2253
# 3 FDZ076-YW-C2-4.bin.102 97.72        3.564              NA   NA
# 4 FDZ076-YW-C2-4.bin.103 47.10        4.921              NA   NA
# 5 FDZ076-YW-C2-4.bin.104 35.50        1.136              NA   NA
# 6 FDZ076-YW-C2-4.bin.105 25.24        0.495              NA   NA

# %%
d95_quality=quality[which(quality$genome %in% tree_summary$SGB),]

# %%
d95_quality %>% mutate(Quality=case_when((completeness>90 & contamination<5) ~ "High",.default="Medium")) ->d95_quality

# %%
d95_quality %>% head
# Out:
#   genome                 completeness contamination length  N50  Quality
# 1 FDZ076-YW-C2-4.bin.275 92.41        3.418         2946517 6882 High
# 2 FDZ033-RR0-2.bin.11    61.56        5.665         2026776 2281 Medium
# 3 FDZ033-RR0-2.bin.80    96.23        1.098         3504034 6749 High
# 4 FDZ050-RBk2-4.bin.114  55.01        3.387         2886268 2600 Medium
# 5 FDZ050-RBk2-4.bin.148  65.22        7.692         3172985 2728 Medium
# 6 FDZ050-RBk2-4.bin.188  84.22        1.676         4361264 3659 Medium

# %%
p <- ggtree(tmp_tree_all_2,color="grey30",layout = "fan",size=.05)+
geom_highlight(data = data.frame(node=mono_node,type=c("Unreported")),mapping = aes(node=node,fill=type),alpha=.7)+
scale_fill_manual(values = c('#FF7F50'))+
guides(fill=guide_legend(reverse = T,title = 'Novelty',title.theme = element_text(size=12,face = "bold"),label.theme = element_text(size=10)))
# First Annotation Layer for Phylum
p2 <- p+new_scale_fill()+geom_fruit(data=tree_anno,geom='geom_tile',aes(y=SGB,fill=Phylum,width=.12),offset = .1,pwidth = .2)+
  scale_fill_manual(values=append(brewer.pal(10,"Paired"),'grey80'))+guides(fill=guide_legend(title = "Phylum",title.theme = element_text(size=12,face = "bold"),label.theme = element_text(size=10)))
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Warning message:
# “The column of x aesthetic only have one unique value with `geom = geom_tile`,
# and the `width` of `geom_tile()` is not provided, the `pwidth` will be as
# `width`.”

# %%
saveRDS(p2,"P2.rds")

# %%
ggsave("tree1_0521.pdf",p2,width=14,height=12)

# %%
sgb_location <- read_tsv("/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/08.profile/meerv2.1/SGB_locations.tsv")
# Out:
# Rows: 7564 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): SGB, Location
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
sgb_location %>% head
# Out:
#   SGB                 Location
# 1 FDZ031YE0-5.bin.230 YT
# 2 FDZ031YE0-5.bin.25  PB-N
# 3 FDZ031YE0-5.bin.262 YT
# 4 FDZ031YE0-5.bin.324 PB-N
# 5 FDZ031YE0-5.bin.33  YT
# 6 FDZ031YE0-5.bin.721 PB-N

# %%
sgb_location %>% mutate(Location=factor(Location,levels=c('MT','YT','PB-N','PB-S'))) ->sgb_location

# %%
Location_color=setNames(c("#FEE090","#DE77AE","#CCEBC5","#1F78B4"),c('MT','YT','PB-N','PB-S'))
p3 <- p2+new_scale_fill()+
geom_fruit(data=sgb_location,geom = "geom_tile",aes(y=SGB,x=Location,fill=Location,width=.06),offset = .04,pwidth = .1)+
scale_fill_manual(values = Location_color) +
guides(fill=guide_legend(title.theme = element_text(size=12,face = "bold"),label.theme = element_text(size=10)))

# %%
p3
# Out:
# Warning message:
# “Removed 1743 rows containing missing values or values outside the scale range
# (`geom_tile()`).”
# plot without title

# %%
ggsave("tree2_0522.pdf",p3,width=14,height=12)
# Out:
# Warning message:
# “Removed 1743 rows containing missing values or values outside the scale range
# (`geom_tile()`).”

# %%
sgb_layergroup <- read_tsv('/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/08.profile/meerv2.1/SGB_layergroup.tsv')
# Out:
# Rows: 7564 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): SGB, LayerGroup
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
sgb_layergroup %>% select(LayerGroup) %>% unique
# Out:
#   LayerGroup
# 1 (0, 10]
# 2 NA
# 3 (10, 20]
# 4 (20, 30]
# 5 (30, 40]

# %%
sgb_layergroup$LayerGroup <- factor(sgb_layergroup$LayerGroup,levels=rev(c("(0, 10]","(10, 20]","(20, 30]","(30, 40]")))

# %%
p4 <- p3+new_scale_fill()+
geom_fruit(data=sgb_layergroup,geom = "geom_tile",aes(y=SGB,x=LayerGroup,fill=LayerGroup,width=.06),offset = .03,pwidth = .1,axis.params = list(axis="y",line.color='grey30'))+
scale_fill_manual(values = rev(c("#e5e8e8","#b1babb","#7e8c8d","#616a6b"))) +
guides(fill=guide_legend(reverse = T,title = 'Sediment Depth',title.theme = element_text(size=12,face = "bold"),label.theme = element_text(size=10)))

# %%
p4
# Out:
# Warning message:
# “Removed 1743 rows containing missing values or values outside the scale range
# (`geom_tile()`).”
# Warning message:
# “Removed 2055 rows containing missing values or values outside the scale range
# (`geom_tile()`).”
# plot without title

# %%
d95_quality %>% mutate(Quality=factor(Quality,levels=c('Medium','High'))) ->d95_quality
p5 <- p4+new_scale_fill()+
geom_fruit(data=d95_quality,geom = "geom_tile",mapping=aes(y=genome,x=Quality,fill=Quality,width=.06),offset = .03,pwidth = .033,axis.params = list(axis="y",line.color='grey30'))+
scale_fill_manual(values=c("#76d7c3","#169f85")) +
guides(fill=guide_legend(reverse = T,title = 'Quality',title.theme = element_text(size=12,face = "bold"),label.theme = element_text(size=10)))+ 
geom_cladelab(node=arc_root,label = "Archaea",fontsize=0,align=T,offset=.02,barcolour="grey40")+
geom_hilight(node=arc_root,fill=NA, color="grey40",linewidth=.2,extendto=1.855)

# %%
library(geomtextpath)

# %%
max(tmp_tree_all_2$x)
# Out:
# [1] 1.79574

# %%
p6 <- p5+geom_textpath(data=data.frame(x=c(1.79,1.79),y=c(7564,6820)),upright=F,size=5,label="Archaea",text_only = T)+
  geom_textpath(data=data.frame(x=c(1.79,1.79),y=c(1,6819)),upright=F,size=5,label="Bacteria",text_only = T)

# %%
ggsave("Prokayotes_MAGs_treeview20240522_v3.pdf",rotate_tree(p6,90),width = 14,height = 12)
# Out:
# Coordinate system already present. Adding new coordinate system, which will
# replace the existing one.
# Warning message:
# “Removed 1743 rows containing missing values or values outside the scale range
# (`geom_tile()`).”
# Warning message:
# “Removed 2055 rows containing missing values or values outside the scale range
# (`geom_tile()`).”

# %%
tree_anno %>% mutate(Quality=(d95_quality %>% column_to_rownames(var='genome'))[tree_anno$SGB,'Quality']) %>%
ggplot(aes(x=Phylum))+geom_bar(aes(fill=Quality),position=position_dodge2())+theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5))
# Out:
# plot without title

# %%
sgb_location_2 <- read_tsv('/dssg/home/acct-trench/trench/USER/zhujiahui/analysis/08.profile/meerv2.1/out.tsv')
# Out:
# Rows: 2122 Columns: 53
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (2): SGB, nearby
# dbl (51): kw.p, FDR, median_Mar.Trench.Bottom, median_Mar.Trench.North, medi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
sgb_location_2 %>% head()
# Out:
#   SGB                 kw.p         FDR          median_Mar.Trench.Bottom
# 1 FDZ031YE0-5.bin.230 6.769735e-08 8.741255e-08 0
# 2 FDZ031YE0-5.bin.25  3.434557e-20 9.498716e-20 0
# 3 FDZ031YE0-5.bin.262 1.029118e-30 6.716351e-30 0
# 4 FDZ031YE0-5.bin.324 9.880256e-51 6.442608e-49 0
# 5 FDZ031YE0-5.bin.33  1.923817e-09 2.664180e-09 0
# 6 FDZ031YE0-5.bin.721 1.593013e-31 1.128235e-30 0
#   median_Mar.Trench.North median_Mar.Trench.South median_MT
# 1 0.00000000              0                       0
# 2 0.00000000              0                       0
# 3 0.03841564              0                       0
# 4 0.00000000              0                       0
# 5 0.00000000              0                       0
# 6 0.00000000              0                       0
#   median_Phi.Basin.North median_Phi.Basin.South median_Yap.Trench ⋯
# 1 0.000000000            0.00000000             0.01565602        ⋯
# 2 0.005169720            0.00000000             0.00000000        ⋯
# 3 0.007616855            0.00000000             0.06072716        ⋯
# 4 0.165815930            0.02661503             0.00000000        ⋯
# 5 0.010899221            0.00000000             0.03892601        ⋯
# 6 0.051373594            0.00000000             0.00000000        ⋯
#   p_Yap.Trench_Phi.Basin.North p_Yap.Trench_Phi.Basin.South
# 1 1.604292e-01                 1.393628e-04
# 2 2.885604e-01                 4.354572e-02
# 3 7.070649e-06                 6.162362e-16
# 4 1.229267e-16                 6.374634e-12
# 5 1.633379e-04                 5.577540e-11
# 6 1.544296e-05                 4.272530e-02
#   mean_rank_Mar.Trench.Bottom mean_rank_Mar.Trench.North
# 1 497.4722                    560.6816
# 2 462.5833                    589.9353
# 3 401.0556                    732.5423
# 4 474.0000                    519.4080
# 5 627.2778                    579.8234
# 6 442.9722                    557.6716
#   mean_rank_Mar.Trench.South mean_rank_MT mean_rank_Phi.Basin.North
# 1 588.6794                   445.0488     663.1299
# 2 546.3895                   471.0976     752.7110
# 3 539.8289                   508.3659     643.2922
# 4 550.8422                   474.0000     804.8377
# 5 579.1777                   628.1220     613.1526
# 6 542.3322                   452.8780     798.2273
#   mean_rank_Phi.Basin.South mean_rank_Yap.Trench
# 1 519.0233                  735.7222
# 2 606.9942                  706.1944
# 3 422.6279                  866.9074
# 4 775.9186                  491.5741
# 5 440.6570                  812.1944
# 6 707.1047                  609.1852
#   nearby
# 1 MT = Mar.Trench.Bottom = Phi.Basin.South = Mar.Trench.North = Mar.Trench.South < Phi.Basin.North = Yap.Trench
# 2 Mar.Trench.Bottom = MT = Mar.Trench.South = Mar.Trench.North = Phi.Basin.South < Yap.Trench = Phi.Basin.North
# 3 Mar.Trench.Bottom = Phi.Basin.South = MT = Mar.Trench.South < Phi.Basin.North < Mar.Trench.North < Yap.Trench
# 4 Mar.Trench.Bottom <=> MT = Yap.Trench = Mar.Trench.North = Mar.Trench.South < Phi.Basin.South = Phi.Basin.North
# 5 Phi.Basin.South < Mar.Trench.South = Mar.Trench.North = Phi.Basin.North = Mar.Trench.Bottom = MT < Yap.Trench
# 6 Mar.Trench.Bottom = MT < Mar.Trench.South = Mar.Trench.North = Yap.Trench < Phi.Basin.South < Phi.Basin.North

# %%
str_split(sgb_$nearby," < ")|> map_chr(\(x) x[length(x)])
# Out:
#    [1] "Phi.Basin.North = Yap.Trench"
#    [2] "Yap.Trench = Phi.Basin.North"
#    [3] "Yap.Trench"
#    [4] "Phi.Basin.South = Phi.Basin.North"
#    [5] "Yap.Trench"
#    [6] "Phi.Basin.North"
#    [7] "Yap.Trench"
#    [8] "Phi.Basin.South <=> Yap.Trench = Mar.Trench = Phi.Basin.North"
#    [9] "Mar.Trench <=> Phi.Basin.South <=> Yap.Trench = Phi.Basin.North"
#   [10] "Mar.Trench <=> Phi.Basin.South <=> Yap.Trench = Phi.Basin.North"
#   [11] "Yap.Trench"
#   [12] "Phi.Basin.North = Yap.Trench"
#   [13] "Mar.Trench <=> Phi.Basin.South <=> Yap.Trench = Phi.Basin.North"
#   [14] "Phi.Basin.North"
#   [15] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
#   [16] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#   [17] "Phi.Basin.North = Yap.Trench"
#   [18] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#   [19] "Yap.Trench"
#   [20] "Phi.Basin.North"
#   [21] "Phi.Basin.North"
#   [22] "Phi.Basin.North"
#   [23] "Phi.Basin.North"
#   [24] "Yap.Trench = Phi.Basin.North"
#   [25] "Yap.Trench"
#   [26] "Phi.Basin.North"
#   [27] "Phi.Basin.North"
#   [28] "Yap.Trench = Phi.Basin.North"
#   [29] "Yap.Trench"
#   [30] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [31] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#   [32] "Yap.Trench = Phi.Basin.North"
#   [33] "Yap.Trench = Phi.Basin.North"
#   [34] "Yap.Trench"
#   [35] "Phi.Basin.North = Yap.Trench"
#   [36] "Phi.Basin.North = Yap.Trench"
#   [37] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#   [38] "Phi.Basin.South = Phi.Basin.North"
#   [39] "Yap.Trench = Phi.Basin.North"
#   [40] "Yap.Trench"
#   [41] "Yap.Trench"
#   [42] "Yap.Trench"
#   [43] "Mar.Trench"
#   [44] "Yap.Trench"
#   [45] "Yap.Trench"
#   [46] "Phi.Basin.North"
#   [47] "Yap.Trench = Phi.Basin.North"
#   [48] "Yap.Trench = Phi.Basin.North"
#   [49] "Mar.Trench = Yap.Trench = Phi.Basin.North = Phi.Basin.South"
#   [50] "Yap.Trench = Phi.Basin.North"
#   [51] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#   [52] "Yap.Trench = Phi.Basin.North"
#   [53] "Phi.Basin.North"
#   [54] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [55] "Phi.Basin.North = Yap.Trench"
#   [56] "Phi.Basin.North = Yap.Trench"
#   [57] "Yap.Trench"
#   [58] "Phi.Basin.South <=> Yap.Trench = Mar.Trench = Phi.Basin.North"
#   [59] "Yap.Trench"
#   [60] "Phi.Basin.North = Yap.Trench"
#   [61] "Phi.Basin.North = Phi.Basin.South"
#   [62] "Yap.Trench = Phi.Basin.North"
#   [63] "Phi.Basin.North = Yap.Trench"
#   [64] "Yap.Trench = Phi.Basin.North"
#   [65] "Phi.Basin.North"
#   [66] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [67] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#   [68] "Yap.Trench"
#   [69] "Phi.Basin.North"
#   [70] "Yap.Trench"
#   [71] "Yap.Trench"
#   [72] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#   [73] "Phi.Basin.North"
#   [74] "Phi.Basin.South = Phi.Basin.North"
#   [75] "Yap.Trench = Phi.Basin.North"
#   [76] "Yap.Trench = Mar.Trench = Phi.Basin.North = Phi.Basin.South"
#   [77] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [78] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [79] "Yap.Trench"
#   [80] "Yap.Trench"
#   [81] "Phi.Basin.North = Yap.Trench"
#   [82] "Yap.Trench = Phi.Basin.North"
#   [83] "Yap.Trench = Phi.Basin.North"
#   [84] "Phi.Basin.North"
#   [85] "Phi.Basin.North = Yap.Trench"
#   [86] "Phi.Basin.North"
#   [87] "Phi.Basin.North"
#   [88] "Yap.Trench"
#   [89] "Yap.Trench"
#   [90] "Phi.Basin.North"
#   [91] "Yap.Trench"
#   [92] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#   [93] "Yap.Trench = Phi.Basin.North"
#   [94] "Yap.Trench"
#   [95] "Phi.Basin.North = Yap.Trench"
#   [96] "Phi.Basin.North"
#   [97] "Yap.Trench = Phi.Basin.North"
#   [98] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#   [99] "Yap.Trench"
#  [100] "Yap.Trench = Phi.Basin.South = Phi.Basin.North = Mar.Trench"
#  [101] "Phi.Basin.North"
#  [102] "Yap.Trench"
#  [103] "Phi.Basin.North"
#  [104] "Phi.Basin.North"
#  [105] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [106] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [107] "Yap.Trench = Phi.Basin.North"
#  [108] "Yap.Trench"
#  [109] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [110] "Phi.Basin.North"
#  [111] "Yap.Trench"
#  [112] "Mar.Trench <=> Phi.Basin.South <=> Yap.Trench = Phi.Basin.North"
#  [113] "Yap.Trench"
#  [114] "Phi.Basin.North = Yap.Trench"
#  [115] "Phi.Basin.North = Yap.Trench"
#  [116] "Phi.Basin.North"
#  [117] "Phi.Basin.North = Yap.Trench"
#  [118] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [119] "Phi.Basin.North = Yap.Trench"
#  [120] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [121] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [122] "Yap.Trench"
#  [123] "Yap.Trench = Phi.Basin.North"
#  [124] "Yap.Trench"
#  [125] "Yap.Trench"
#  [126] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [127] "Yap.Trench"
#  [128] "Yap.Trench = Phi.Basin.North"
#  [129] "Yap.Trench"
#  [130] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [131] "Phi.Basin.North = Yap.Trench"
#  [132] "Yap.Trench = Phi.Basin.North"
#  [133] "Yap.Trench"
#  [134] "Phi.Basin.North"
#  [135] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [136] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [137] "Phi.Basin.North = Yap.Trench"
#  [138] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [139] "Phi.Basin.North = Yap.Trench"
#  [140] "Mar.Trench = Yap.Trench"
#  [141] "Yap.Trench"
#  [142] "Mar.Trench = Phi.Basin.North"
#  [143] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [144] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [145] "Yap.Trench"
#  [146] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [147] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [148] "Phi.Basin.North"
#  [149] "Phi.Basin.North"
#  [150] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [151] "Yap.Trench"
#  [152] "Yap.Trench = Phi.Basin.North = Mar.Trench"
#  [153] "Yap.Trench"
#  [154] "Yap.Trench"
#  [155] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [156] "Yap.Trench = Phi.Basin.North"
#  [157] "Phi.Basin.North = Yap.Trench"
#  [158] "Phi.Basin.North = Yap.Trench"
#  [159] "Phi.Basin.North"
#  [160] "Phi.Basin.North"
#  [161] "Yap.Trench"
#  [162] "Phi.Basin.South = Phi.Basin.North"
#  [163] "Phi.Basin.North"
#  [164] "Phi.Basin.North"
#  [165] "Yap.Trench = Phi.Basin.North"
#  [166] "Phi.Basin.North"
#  [167] "Yap.Trench = Phi.Basin.North"
#  [168] "Phi.Basin.North"
#  [169] "Phi.Basin.North"
#  [170] "Yap.Trench"
#  [171] "Yap.Trench = Phi.Basin.North"
#  [172] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [173] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [174] "Phi.Basin.North"
#  [175] "Yap.Trench"
#  [176] "Phi.Basin.North = Yap.Trench"
#  [177] "Yap.Trench = Phi.Basin.North"
#  [178] "Phi.Basin.North = Yap.Trench"
#  [179] "Phi.Basin.North = Yap.Trench"
#  [180] "Phi.Basin.North = Yap.Trench"
#  [181] "Phi.Basin.North"
#  [182] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [183] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [184] "Phi.Basin.North"
#  [185] "Yap.Trench"
#  [186] "Phi.Basin.North = Yap.Trench"
#  [187] "Phi.Basin.North = Yap.Trench"
#  [188] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [189] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [190] "Phi.Basin.North"
#  [191] "Phi.Basin.North = Phi.Basin.South"
#  [192] "Yap.Trench"
#  [193] "Mar.Trench = Yap.Trench"
#  [194] "Phi.Basin.North = Yap.Trench"
#  [195] "Yap.Trench"
#  [196] "Phi.Basin.North = Yap.Trench"
#  [197] "Yap.Trench"
#  [198] "Yap.Trench = Phi.Basin.North"
#  [199] "Yap.Trench"
#  [200] "Yap.Trench"
#  [201] "Phi.Basin.North"
#  [202] "Phi.Basin.North = Yap.Trench"
#  [203] "Yap.Trench"
#  [204] "Phi.Basin.North = Yap.Trench"
#  [205] "Yap.Trench"
#  [206] "Yap.Trench"
#  [207] "Yap.Trench"
#  [208] "Yap.Trench"
#  [209] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [210] "Yap.Trench"
#  [211] "Phi.Basin.North = Yap.Trench"
#  [212] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [213] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [214] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#  [215] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
#  [216] "Mar.Trench = Yap.Trench"
#  [217] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [218] "Yap.Trench"
#  [219] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [220] "Yap.Trench"
#  [221] "Yap.Trench"
#  [222] "Phi.Basin.North"
#  [223] "Yap.Trench = Phi.Basin.North"
#  [224] "Phi.Basin.North = Yap.Trench"
#  [225] "Phi.Basin.North"
#  [226] "Phi.Basin.North = Yap.Trench"
#  [227] "Phi.Basin.North"
#  [228] "Phi.Basin.North = Yap.Trench"
#  [229] "Yap.Trench"
#  [230] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [231] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [232] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [233] "Phi.Basin.North"
#  [234] "Yap.Trench = Phi.Basin.North"
#  [235] "Phi.Basin.North = Yap.Trench"
#  [236] "Yap.Trench = Phi.Basin.North"
#  [237] "Yap.Trench"
#  [238] "Yap.Trench"
#  [239] "Yap.Trench"
#  [240] "Yap.Trench"
#  [241] "Phi.Basin.North"
#  [242] "Phi.Basin.North"
#  [243] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#  [244] "Yap.Trench"
#  [245] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [246] "Yap.Trench = Phi.Basin.North"
#  [247] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [248] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [249] "Phi.Basin.South = Phi.Basin.North"
#  [250] "Yap.Trench"
#  [251] "Phi.Basin.North"
#  [252] "Yap.Trench"
#  [253] "Yap.Trench"
#  [254] "Phi.Basin.North"
#  [255] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [256] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#  [257] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [258] "Phi.Basin.North = Yap.Trench"
#  [259] "Phi.Basin.North = Yap.Trench"
#  [260] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
#  [261] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [262] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [263] "Phi.Basin.North"
#  [264] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [265] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [266] "Phi.Basin.North = Yap.Trench"
#  [267] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [268] "Yap.Trench"
#  [269] "Phi.Basin.North"
#  [270] "Phi.Basin.South = Phi.Basin.North"
#  [271] "Phi.Basin.North = Phi.Basin.South = Mar.Trench = Yap.Trench"
#  [272] "Yap.Trench"
#  [273] "Yap.Trench"
#  [274] "Phi.Basin.North = Yap.Trench"
#  [275] "Phi.Basin.North = Yap.Trench"
#  [276] "Phi.Basin.North = Yap.Trench"
#  [277] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [278] "Yap.Trench"
#  [279] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [280] "Yap.Trench"
#  [281] "Phi.Basin.North"
#  [282] "Yap.Trench = Phi.Basin.North"
#  [283] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [284] "Mar.Trench = Yap.Trench"
#  [285] "Mar.Trench"
#  [286] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [287] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [288] "Yap.Trench"
#  [289] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [290] "Phi.Basin.North"
#  [291] "Phi.Basin.North"
#  [292] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [293] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [294] "Yap.Trench = Phi.Basin.North"
#  [295] "Phi.Basin.North"
#  [296] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [297] "Yap.Trench"
#  [298] "Phi.Basin.North"
#  [299] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [300] "Yap.Trench"
#  [301] "Yap.Trench"
#  [302] "Yap.Trench"
#  [303] "Yap.Trench"
#  [304] "Yap.Trench"
#  [305] "Yap.Trench"
#  [306] "Yap.Trench"
#  [307] "Yap.Trench"
#  [308] "Yap.Trench = Phi.Basin.North"
#  [309] "Mar.Trench = Yap.Trench"
#  [310] "Phi.Basin.South"
#  [311] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [312] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [313] "Phi.Basin.North"
#  [314] "Phi.Basin.North"
#  [315] "Phi.Basin.North = Phi.Basin.South = Yap.Trench"
#  [316] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [317] "Phi.Basin.North"
#  [318] "Phi.Basin.North"
#  [319] "Phi.Basin.North"
#  [320] "Yap.Trench = Phi.Basin.South = Mar.Trench = Phi.Basin.North"
#  [321] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [322] "Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [323] "Phi.Basin.North"
#  [324] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [325] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [326] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [327] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [328] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [329] "Yap.Trench"
#  [330] "Phi.Basin.North = Yap.Trench"
#  [331] "Phi.Basin.North = Yap.Trench"
#  [332] "Yap.Trench = Phi.Basin.North"
#  [333] "Phi.Basin.North"
#  [334] "Yap.Trench = Phi.Basin.North"
#  [335] "Phi.Basin.North"
#  [336] "Yap.Trench = Phi.Basin.North"
#  [337] "Yap.Trench"
#  [338] "Yap.Trench"
#  [339] "Phi.Basin.North"
#  [340] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [341] "Yap.Trench = Phi.Basin.North"
#  [342] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [343] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [344] "Yap.Trench"
#  [345] "Yap.Trench"
#  [346] "Phi.Basin.North"
#  [347] "Phi.Basin.North"
#  [348] "Phi.Basin.North = Yap.Trench"
#  [349] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#  [350] "Phi.Basin.North"
#  [351] "Yap.Trench = Phi.Basin.North = Phi.Basin.South = Mar.Trench"
#  [352] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [353] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [354] "Yap.Trench"
#  [355] "Phi.Basin.North"
#  [356] "Yap.Trench"
#  [357] "Yap.Trench"
#  [358] "Phi.Basin.North"
#  [359] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [360] "Phi.Basin.North"
#  [361] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [362] "Phi.Basin.South <=> Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [363] "Yap.Trench"
#  [364] "Yap.Trench = Phi.Basin.North"
#  [365] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
#  [366] "Yap.Trench"
#  [367] "Phi.Basin.North"
#  [368] "Phi.Basin.North = Yap.Trench"
#  [369] "Phi.Basin.North"
#  [370] "Yap.Trench = Phi.Basin.North = Mar.Trench = Phi.Basin.South"
#  [371] "Yap.Trench"
#  [372] "Phi.Basin.North"
#  [373] "Yap.Trench"
#  [374] "Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [375] "Yap.Trench"
#  [376] "Phi.Basin.North = Yap.Trench"
#  [377] "Phi.Basin.North = Yap.Trench"
#  [378] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [379] "Yap.Trench"
#  [380] "Yap.Trench"
#  [381] "Yap.Trench"
#  [382] "Yap.Trench"
#  [383] "Yap.Trench"
#  [384] "Phi.Basin.North"
#  [385] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [386] "Phi.Basin.North"
#  [387] "Phi.Basin.North"
#  [388] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [389] "Yap.Trench"
#  [390] "Yap.Trench"
#  [391] "Phi.Basin.North = Yap.Trench"
#  [392] "Yap.Trench = Phi.Basin.North"
#  [393] "Phi.Basin.North"
#  [394] "Phi.Basin.North"
#  [395] "Phi.Basin.North"
#  [396] "Yap.Trench"
#  [397] "Phi.Basin.North"
#  [398] "Phi.Basin.North = Yap.Trench"
#  [399] "Phi.Basin.North = Yap.Trench"
#  [400] "Phi.Basin.North = Yap.Trench"
#  [401] "Yap.Trench"
#  [402] "Yap.Trench"
#  [403] "Phi.Basin.North"
#  [404] "Phi.Basin.North = Yap.Trench"
#  [405] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [406] "Phi.Basin.North"
#  [407] "Mar.Trench"
#  [408] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [409] "Yap.Trench"
#  [410] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [411] "Yap.Trench"
#  [412] "Phi.Basin.North = Yap.Trench"
#  [413] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [414] "Phi.Basin.North = Yap.Trench"
#  [415] "Phi.Basin.North"
#  [416] "Phi.Basin.North"
#  [417] "Phi.Basin.North"
#  [418] "Yap.Trench"
#  [419] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [420] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [421] "Phi.Basin.North"
#  [422] "Phi.Basin.North"
#  [423] "Phi.Basin.South = Phi.Basin.North"
#  [424] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [425] "Phi.Basin.North = Yap.Trench"
#  [426] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [427] "Phi.Basin.North = Yap.Trench"
#  [428] "Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [429] "Yap.Trench"
#  [430] "Phi.Basin.North"
#  [431] "Yap.Trench"
#  [432] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [433] "Phi.Basin.North = Yap.Trench"
#  [434] "Phi.Basin.North"
#  [435] "Mar.Trench"
#  [436] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [437] "Yap.Trench = Mar.Trench"
#  [438] "Yap.Trench"
#  [439] "Phi.Basin.South = Phi.Basin.North"
#  [440] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [441] "Yap.Trench"
#  [442] "Phi.Basin.North"
#  [443] "Phi.Basin.North = Yap.Trench"
#  [444] "Phi.Basin.North"
#  [445] "Phi.Basin.North = Yap.Trench"
#  [446] "Yap.Trench"
#  [447] "Phi.Basin.North"
#  [448] "Phi.Basin.North"
#  [449] "Phi.Basin.North"
#  [450] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [451] "Phi.Basin.North = Yap.Trench"
#  [452] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [453] "Yap.Trench"
#  [454] "Phi.Basin.North"
#  [455] "Phi.Basin.North"
#  [456] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [457] "Phi.Basin.North"
#  [458] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [459] "Phi.Basin.North"
#  [460] "Yap.Trench"
#  [461] "Phi.Basin.North"
#  [462] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [463] "Yap.Trench"
#  [464] "Phi.Basin.North = Yap.Trench"
#  [465] "Yap.Trench"
#  [466] "Yap.Trench = Phi.Basin.North"
#  [467] "Mar.Trench = Yap.Trench"
#  [468] "Phi.Basin.North"
#  [469] "Phi.Basin.South = Phi.Basin.North"
#  [470] "Yap.Trench"
#  [471] "Phi.Basin.North"
#  [472] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [473] "Phi.Basin.North"
#  [474] "Yap.Trench"
#  [475] "Yap.Trench"
#  [476] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [477] "Phi.Basin.North = Yap.Trench"
#  [478] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [479] "Mar.Trench = Phi.Basin.North"
#  [480] "Yap.Trench"
#  [481] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [482] "Phi.Basin.North"
#  [483] "Phi.Basin.North = Yap.Trench"
#  [484] "Yap.Trench"
#  [485] "Phi.Basin.North = Yap.Trench"
#  [486] "Phi.Basin.North"
#  [487] "Yap.Trench = Phi.Basin.South = Phi.Basin.North = Mar.Trench"
#  [488] "Phi.Basin.North"
#  [489] "Mar.Trench = Yap.Trench"
#  [490] "Phi.Basin.North"
#  [491] "Phi.Basin.North = Yap.Trench"
#  [492] "Phi.Basin.North"
#  [493] "Yap.Trench = Phi.Basin.North"
#  [494] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [495] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [496] "Phi.Basin.North = Yap.Trench"
#  [497] "Phi.Basin.South = Phi.Basin.North = Mar.Trench"
#  [498] "Phi.Basin.North"
#  [499] "Phi.Basin.South = Phi.Basin.North"
#  [500] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [501] "Yap.Trench"
#  [502] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [503] "Yap.Trench"
#  [504] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [505] "Phi.Basin.North"
#  [506] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [507] "Yap.Trench"
#  [508] "Phi.Basin.North"
#  [509] "Yap.Trench"
#  [510] "Phi.Basin.North = Yap.Trench"
#  [511] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [512] "Mar.Trench = Yap.Trench"
#  [513] "Yap.Trench"
#  [514] "Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [515] "Phi.Basin.North"
#  [516] "Phi.Basin.North"
#  [517] "Yap.Trench"
#  [518] "Phi.Basin.North"
#  [519] "Yap.Trench"
#  [520] "Phi.Basin.North = Yap.Trench"
#  [521] "Phi.Basin.North = Yap.Trench"
#  [522] "Yap.Trench"
#  [523] "Yap.Trench"
#  [524] "Yap.Trench = Mar.Trench"
#  [525] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [526] "Phi.Basin.North"
#  [527] "Yap.Trench"
#  [528] "Phi.Basin.North"
#  [529] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [530] "Phi.Basin.North"
#  [531] "Phi.Basin.North"
#  [532] "Yap.Trench"
#  [533] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [534] "Yap.Trench = Phi.Basin.North"
#  [535] "Yap.Trench"
#  [536] "Yap.Trench"
#  [537] "Yap.Trench"
#  [538] "Yap.Trench"
#  [539] "Yap.Trench"
#  [540] "Phi.Basin.North"
#  [541] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [542] "Yap.Trench"
#  [543] "Phi.Basin.North = Yap.Trench"
#  [544] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [545] "Mar.Trench = Yap.Trench"
#  [546] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [547] "Yap.Trench"
#  [548] "Yap.Trench"
#  [549] "Yap.Trench"
#  [550] "Yap.Trench"
#  [551] "Phi.Basin.South <=> Yap.Trench = Phi.Basin.North = Mar.Trench"
#  [552] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [553] "Phi.Basin.North = Yap.Trench"
#  [554] "Yap.Trench"
#  [555] "Phi.Basin.North"
#  [556] "Phi.Basin.North"
#  [557] "Mar.Trench = Phi.Basin.North"
#  [558] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [559] "Phi.Basin.North = Phi.Basin.South = Mar.Trench = Yap.Trench"
#  [560] "Yap.Trench"
#  [561] "Phi.Basin.North"
#  [562] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [563] "Yap.Trench"
#  [564] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [565] "Mar.Trench = Yap.Trench"
#  [566] "Phi.Basin.North = Yap.Trench"
#  [567] "Phi.Basin.North"
#  [568] "Phi.Basin.North"
#  [569] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [570] "Yap.Trench"
#  [571] "Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [572] "Yap.Trench"
#  [573] "Yap.Trench"
#  [574] "Mar.Trench = Yap.Trench"
#  [575] "Yap.Trench"
#  [576] "Phi.Basin.North"
#  [577] "Phi.Basin.South = Yap.Trench = Phi.Basin.North = Mar.Trench"
#  [578] "Yap.Trench"
#  [579] "Phi.Basin.South = Yap.Trench = Phi.Basin.North = Mar.Trench"
#  [580] "Phi.Basin.North = Yap.Trench"
#  [581] "Yap.Trench"
#  [582] "Yap.Trench = Mar.Trench"
#  [583] "Yap.Trench"
#  [584] "Yap.Trench"
#  [585] "Yap.Trench"
#  [586] "Yap.Trench"
#  [587] "Phi.Basin.North = Yap.Trench"
#  [588] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [589] "Yap.Trench"
#  [590] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
#  [591] "Yap.Trench = Mar.Trench"
#  [592] "Yap.Trench"
#  [593] "Yap.Trench"
#  [594] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [595] "Yap.Trench"
#  [596] "Yap.Trench"
#  [597] "Yap.Trench"
#  [598] "Yap.Trench"
#  [599] "Yap.Trench"
#  [600] "Yap.Trench = Phi.Basin.North"
#  [601] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
#  [602] "Yap.Trench"
#  [603] "Yap.Trench"
#  [604] "Mar.Trench = Phi.Basin.North"
#  [605] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [606] "Yap.Trench"
#  [607] "Yap.Trench = Phi.Basin.North"
#  [608] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [609] "Yap.Trench"
#  [610] "Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [611] "Yap.Trench"
#  [612] "Yap.Trench = Phi.Basin.North"
#  [613] "Yap.Trench"
#  [614] "Phi.Basin.North = Yap.Trench"
#  [615] "Yap.Trench"
#  [616] "Yap.Trench"
#  [617] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [618] "Phi.Basin.North"
#  [619] "Phi.Basin.North"
#  [620] "Phi.Basin.North"
#  [621] "Yap.Trench"
#  [622] "Phi.Basin.South = Phi.Basin.North"
#  [623] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
#  [624] "Phi.Basin.North = Mar.Trench = Yap.Trench"
#  [625] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
#  [626] "Yap.Trench"
#  [627] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
#  [628] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [629] "Yap.Trench"
#  [630] "Phi.Basin.South = Phi.Basin.North"
#  [631] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
#  [632] "Mar.Trench"
#  [633] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
#  [634] "Yap.Trench"
#  [635] "Phi.Basin.North = Yap.Trench"
#  [636] "Yap.Trench = Mar.Trench = Phi.Basin.North = Phi.Basin.South"
#  [637] "Phi.Basin.North"
#  [638] "Phi.Basin.North"
#  [639] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
#  [640] "Phi.Basin.North"
# ...
# [7352] "Phi.Basin.North = Phi.Basin.South"
# [7353] "Phi.Basin.South"
# [7354] "Phi.Basin.North = Phi.Basin.South"
# [7355] "Phi.Basin.North = Phi.Basin.South"
# [7356] "Yap.Trench"
# [7357] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
# [7358] "Yap.Trench"
# [7359] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7360] "Yap.Trench"
# [7361] "Phi.Basin.South"
# [7362] "Phi.Basin.South = Phi.Basin.North"
# [7363] "Mar.Trench = Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7364] "Yap.Trench"
# [7365] "Phi.Basin.North = Phi.Basin.South = Mar.Trench = Yap.Trench"
# [7366] "Phi.Basin.North"
# [7367] "Yap.Trench"
# [7368] "Phi.Basin.North = Phi.Basin.South = Yap.Trench"
# [7369] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7370] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7371] "Yap.Trench"
# [7372] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
# [7373] "Phi.Basin.South"
# [7374] "Yap.Trench = Phi.Basin.South = Mar.Trench = Phi.Basin.North"
# [7375] "Yap.Trench = Mar.Trench = Phi.Basin.North = Phi.Basin.South"
# [7376] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
# [7377] "Phi.Basin.South"
# [7378] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
# [7379] "Yap.Trench = Mar.Trench = Phi.Basin.North = Phi.Basin.South"
# [7380] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7381] "Phi.Basin.South"
# [7382] "Phi.Basin.South"
# [7383] "Mar.Trench <=> Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7384] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7385] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7386] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
# [7387] "Yap.Trench = Mar.Trench = Phi.Basin.North = Phi.Basin.South"
# [7388] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
# [7389] "Phi.Basin.North = Yap.Trench = Phi.Basin.South = Mar.Trench"
# [7390] "Yap.Trench"
# [7391] "Mar.Trench <=> Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7392] "Phi.Basin.South"
# [7393] "Mar.Trench <=> Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7394] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
# [7395] "Phi.Basin.South"
# [7396] "Phi.Basin.South"
# [7397] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
# [7398] "Mar.Trench <=> Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7399] "Phi.Basin.South"
# [7400] "Yap.Trench = Phi.Basin.South = Phi.Basin.North = Mar.Trench"
# [7401] "Mar.Trench = Phi.Basin.North = Yap.Trench = Phi.Basin.South"
# [7402] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
# [7403] "Phi.Basin.South"
# [7404] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7405] "Phi.Basin.South"
# [7406] "Mar.Trench = Yap.Trench"
# [7407] "Yap.Trench"
# [7408] "Mar.Trench = Yap.Trench"
# [7409] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7410] "Yap.Trench = Phi.Basin.South = Mar.Trench = Phi.Basin.North"
# [7411] "Yap.Trench"
# [7412] "Mar.Trench = Yap.Trench"
# [7413] "Mar.Trench = Yap.Trench"
# [7414] "Yap.Trench"
# [7415] "Mar.Trench = Yap.Trench"
# [7416] "Yap.Trench"
# [7417] "Phi.Basin.North = Yap.Trench"
# [7418] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7419] "Phi.Basin.South = Phi.Basin.North"
# [7420] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7421] "Mar.Trench = Yap.Trench"
# [7422] "Yap.Trench"
# [7423] "Yap.Trench"
# [7424] "Mar.Trench = Yap.Trench"
# [7425] "Phi.Basin.North = Phi.Basin.South = Mar.Trench = Yap.Trench"
# [7426] "Mar.Trench = Yap.Trench"
# [7427] "Mar.Trench = Yap.Trench"
# [7428] "Mar.Trench = Yap.Trench"
# [7429] "Yap.Trench"
# [7430] "Yap.Trench"
# [7431] "Yap.Trench"
# [7432] "Yap.Trench"
# [7433] "Mar.Trench = Yap.Trench"
# [7434] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
# [7435] "Yap.Trench = Mar.Trench"
# [7436] "Mar.Trench"
# [7437] "Mar.Trench"
# [7438] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
# [7439] "Yap.Trench = Phi.Basin.North = Phi.Basin.South = Mar.Trench"
# [7440] "Phi.Basin.North = Yap.Trench = Phi.Basin.South = Mar.Trench"
# [7441] "Yap.Trench"
# [7442] "Yap.Trench"
# [7443] "Yap.Trench = Mar.Trench"
# [7444] "Mar.Trench = Yap.Trench"
# [7445] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7446] "Yap.Trench"
# [7447] "Mar.Trench = Yap.Trench"
# [7448] "Yap.Trench = Phi.Basin.North = Phi.Basin.South = Mar.Trench"
# [7449] "Mar.Trench"
# [7450] "Yap.Trench"
# [7451] "Yap.Trench"
# [7452] "Phi.Basin.North"
# [7453] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
# [7454] "Phi.Basin.North = Yap.Trench"
# [7455] "Phi.Basin.North = Yap.Trench = Phi.Basin.South"
# [7456] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7457] "Mar.Trench = Phi.Basin.South = Phi.Basin.North = Yap.Trench"
# [7458] "Mar.Trench = Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7459] "Yap.Trench"
# [7460] "Phi.Basin.South = Phi.Basin.North"
# [7461] "Yap.Trench"
# [7462] "Phi.Basin.South = Yap.Trench = Mar.Trench = Phi.Basin.North"
# [7463] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7464] "Phi.Basin.South = Phi.Basin.North"
# [7465] "Yap.Trench = Phi.Basin.North"
# [7466] "Phi.Basin.North"
# [7467] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7468] "Phi.Basin.South = Phi.Basin.North"
# [7469] "Yap.Trench"
# [7470] "Phi.Basin.South = Mar.Trench = Yap.Trench = Phi.Basin.North"
# [7471] "Phi.Basin.South"
# [7472] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7473] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7474] "Mar.Trench = Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7475] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7476] "Phi.Basin.North = Yap.Trench"
# [7477] "Phi.Basin.North = Phi.Basin.South"
# [7478] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7479] "Yap.Trench = Phi.Basin.North = Phi.Basin.South"
# [7480] "Yap.Trench"
# [7481] "Phi.Basin.North"
# [7482] "Phi.Basin.South"
# [7483] "Yap.Trench = Mar.Trench"
# [7484] "Yap.Trench"
# [7485] "Phi.Basin.North <=> Yap.Trench = Mar.Trench <=> Phi.Basin.South"
# [7486] "Yap.Trench"
# [7487] "Yap.Trench"
# [7488] "Yap.Trench = Phi.Basin.North = Phi.Basin.South = Mar.Trench"
# [7489] "Mar.Trench"
# [7490] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7491] "Yap.Trench"
# [7492] "Yap.Trench"
# [7493] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
# [7494] "Mar.Trench = Yap.Trench"
# [7495] "Yap.Trench"
# [7496] "Yap.Trench"
# [7497] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7498] "Phi.Basin.North"
# [7499] "Phi.Basin.South = Phi.Basin.North = Mar.Trench = Yap.Trench"
# [7500] "Phi.Basin.North"
# [7501] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7502] "Phi.Basin.South = Phi.Basin.North = Yap.Trench = Mar.Trench"
# [7503] "Phi.Basin.South = Phi.Basin.North"
# [7504] "Phi.Basin.North"
# [7505] "Phi.Basin.South"
# [7506] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
# [7507] "Mar.Trench"
# [7508] "Yap.Trench"
# [7509] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7510] "Phi.Basin.South"
# [7511] "Yap.Trench"
# [7512] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7513] "Yap.Trench"
# [7514] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
# [7515] "Phi.Basin.North = Yap.Trench"
# [7516] "Phi.Basin.North = Phi.Basin.South"
# [7517] "Phi.Basin.South = Phi.Basin.North"
# [7518] "Yap.Trench"
# [7519] "Yap.Trench"
# [7520] "Phi.Basin.South = Phi.Basin.North"
# [7521] "Phi.Basin.South"
# [7522] "Yap.Trench = Mar.Trench = Phi.Basin.South = Phi.Basin.North"
# [7523] "Yap.Trench = Phi.Basin.South = Phi.Basin.North"
# [7524] "Phi.Basin.South"
# [7525] "Phi.Basin.South = Phi.Basin.North"
# [7526] "Yap.Trench"
# [7527] "Mar.Trench = Yap.Trench"
# [7528] "Yap.Trench"
# [7529] "Mar.Trench"
# [7530] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7531] "Phi.Basin.South = Mar.Trench = Yap.Trench"
# [7532] "Yap.Trench"
# [7533] "Phi.Basin.North = Phi.Basin.South = Mar.Trench = Yap.Trench"
# [7534] "Yap.Trench"
# [7535] "Phi.Basin.North = Phi.Basin.South = Yap.Trench = Mar.Trench"
# [7536] "Yap.Trench"
# [7537] "Yap.Trench"
# [7538] "Yap.Trench"
# [7539] "Yap.Trench"
# [7540] "Phi.Basin.North = Mar.Trench = Yap.Trench"
# [7541] "Yap.Trench"
# [7542] "Yap.Trench"
# [7543] "Yap.Trench"
# [7544] "Yap.Trench"
# [7545] "Yap.Trench"
# [7546] "Mar.Trench = Yap.Trench"
# [7547] "Mar.Trench = Yap.Trench"
# [7548] "Mar.Trench = Yap.Trench"
# [7549] "Yap.Trench"
# [7550] "Yap.Trench"
# [7551] "Yap.Trench"
# [7552] "Yap.Trench"
# [7553] "Yap.Trench"
# [7554] "Yap.Trench"
# [7555] "Mar.Trench = Yap.Trench"
# [7556] "Yap.Trench"
# [7557] "Phi.Basin.North"
# [7558] "Phi.Basin.South = Phi.Basin.North = Yap.Trench"
# [7559] "Phi.Basin.South = Mar.Trench = Phi.Basin.North = Yap.Trench"
# [7560] "Phi.Basin.North = Phi.Basin.South"
# [7561] "Mar.Trench = Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7562] "Phi.Basin.South"
# [7563] "Phi.Basin.South = Yap.Trench = Phi.Basin.North"
# [7564] "Phi.Basin.North = Yap.Trench"

# %%
single_arc_node %>% mutate(node=case_when(grepl(",",Leaf_Names)~"node",.default="leaf")) ->single_arc_node_2

# %%
rank_color=setNames(c("#E63946","#ffa200","#0087cb","#24a8ac","#98DF8A"),c("Phylum","Class","Order","Family","Genus"))
single_arc_node %>% mutate(rank=factor(str_to_title(rank),levels=c("Phylum","Class","Order","Family","Genus"))) %>% 
    ggplot()+geom_histogram(aes(x=RED,fill=rank),binwidth=.025)+theme_classic()+ggtitle("Archaea Monophyletic Clade RED Distribution")+
    scale_fill_manual(values =  rank_color,name='Rank') ->single_arc_distribute

# %%
single_arc_distribute
# Out:
# plot without title

# %%
single_bac_node %>% mutate(rank=factor(str_to_title(rank),levels=c("Phylum","Class","Order","Family","Genus"))) %>% 
    ggplot()+geom_histogram(aes(x=RED,fill=rank),binwidth=.025)+theme_classic()+ggtitle("Bacteria Monophyletic Clade RED Distribution")+
    scale_fill_manual(values =rank_color,name='Rank') ->single_bac_distribute

# %%
single_bac_distribute
# Out:
# plot without title

# %%
single_bac_distribute +single_arc_distribute +plot_layout(guide = 'collect') ->RED_distribute

# %%
RED_distribute
# Out:
# plot without title

# %%
ggsave("TREE_Monophyletic_RED_histogram_0523.pdf",RED_distribute,width = 12,height = 5)

# %%
unclassified_species %>% mutate(status=case_when(Genus=="" ~ "Genus+", .default="Species")) ->unclassified_species

# %%
library(networkD3)
# tree_summary$classified <- tree_summary$Species==""
# unclassified_species<-tree_summary[which(tree_summary$classified==TRUE),c("Kingdom","Phylum","Genus","Species")]
# unclassified_species %>% mutate(status=case_when(Genus=="" ~ "Genus+", .default="Species")) ->unclassified_species

alluvial_unknown <- unclassified_species[,c("Kingdom","Phylum","status")]
alluvial_unknown[which(alluvial_unknown$Phylum==""),"Phylum"] <- "Unclassified"
alluvial_freq <- alluvial_unknown%>% group_by(Kingdom,Phylum,status) %>%  count()
bacteria_alluvial <- alluvial_unknown %>% group_by(Kingdom,Phylum) %>%  count() %>%filter(Kingdom=="Bacteria")%>%arrange(desc(n))
bac_top15 <- bacteria_alluvial[1:15,"Phylum"]
archaea_alluvial <- alluvial_unknown %>% group_by(Kingdom,Phylum) %>%  count() %>%filter(Kingdom=="Archaea")%>%arrange(desc(n))
arc_top <- archaea_alluvial[,"Phylum"]
phylum_level <- arc_top %>% bind_rows(bac_top15)
plot_allu_feq <- alluvial_freq %>% filter(Phylum %in% as.matrix(phylum_level))

source_target1 <- alluvial_unknown %>% group_by(Kingdom,Phylum) %>%  count() %>% filter(Phylum %in% as.matrix(phylum_level)) %>% as.data.frame()
colnames(source_target1) <- c("source","target","value")
source_target2 <- alluvial_unknown %>% group_by(Phylum,status) %>%  count() %>% filter(Phylum %in% as.matrix(phylum_level))%>%as.data.frame()
colnames(source_target2) <- c("source","target","value")
source_target <- source_target1 %>% bind_rows(source_target2) %>% as.data.frame()
colnames(source_target) <- c("source","target","value")

nodes <- data.frame(
  name=c(as.character(source_target$source), 
  as.character(source_target$target)) %>% unique()
)
source_target$IDsource <- match(source_target$source, nodes$name)-1 
source_target$IDtarget <- match(source_target$target, nodes$name)-1
nw <- sankeyNetwork(Links = source_target, Nodes = nodes,
              Source = "IDsource", Target = "IDtarget",
              Value = "value", NodeID = "name", 
              sinksRight=FALSE,
              width = 500,
              height = 500,
              fontSize=12,nodeWidth=10,nodePadding = 6,
              fontFamily="Arial")
saveNetwork(nw,"Prokayotes_Classification_Sankey.html")
# Out:
# Error in pandoc_self_contained_html(file, file): Saving a widget with selfcontained = TRUE requires pandoc. See here to learn more https://bookdown.org/yihui/rmarkdown-cookbook/install-pandoc.html
# Traceback:
#
# 1. saveNetwork(nw, "Prokayotes_Classification_Sankey.html")
# 2. htmlwidgets::saveWidget(network, file, selfcontained)
# 3. pandoc_self_contained_html(file, file)
# 4. stop("Saving a widget with selfcontained = TRUE requires pandoc. ",
#  .     "See here to learn more https://bookdown.org/yihui/rmarkdown-cookbook/install-pandoc.html")

# %%
saveRDS(nw,'nw.rds')

# %%
tree_summary %>% group_by(Phylum,Species) %>% count %>% filter(Species=="") %>% arrange(desc(n))
# Out:
#    Phylum              Species n
# 1  Chloroflexota               1148
# 2  Patescibacteria             1125
# 3  Planctomycetota             1069
# 4  Pseudomonadota               847
# 5  Nanoarchaeota                640
# 6  Bacteroidota                 317
# 7  Marinisomatota               147
# 8  Hydrogenedentota             146
# 9  Zixibacteria                 142
# 10 Omnitrophota                 136
# 11 Acidobacteriota              108
# 12 Gemmatimonadota              106
# 13 Myxococcota_A                 74
# 14 Verrucomicrobiota             56
# 15 Armatimonadota                53
# 16 Actinomycetota                52
# 17 Elusimicrobiota               52
# 18 Nitrospinota                  49
# 19 SAR324                        41
# 20 Nitrospirota                  40
# 21 Sumerlaeota                   40
# 22 Myxococcota                   38
# 23 Thermoproteota                30
# 24 Latescibacterota              20
# 25 Krumholzibacteriota           17
# 26 Bdellovibrionota              16
# 27 Chlamydiota                   16
# 28 KSB1                          16
# 29 SM23-31                       16
# 30 Iainarchaeota                 15
# ⋮  ⋮                   ⋮       ⋮
# 51 Poribacteria                3
# 52 Thermoplasmatota            3
# 53 UBA10199                    3
# 54 UBP7                        3
# 55 Atribacterota               2
# 56 Bacillota                   2
# 57 Calditrichota               2
# 58 GCA-001730085               2
# 59 JAGRBM01                    2
# 60 JdFR-76                     2
# 61 Lernaellota                 2
# 62 Margulisbacteria            2
# 63 UBP15                       2
# 64 ARS69                       1
# 65 Abyssobacteria              1
# 66 Aerophobota                 1
# 67 Bdellovibrionota_G          1
# 68 Fibrobacterota              1
# 69 GCA-2686955                 1
# 70 Hydrothermarchaeota         1
# 71 JAAXHH01                    1
# 72 JABMQX01                    1
# 73 JADJOY01                    1
# 74 JAHJDO01                    1
# 75 JAKLEM01                    1
# 76 JAUYMQ01                    1
# 77 NPL-UPA2                    1
# 78 UBP18                       1
# 79 Undinarchaeota              1
# 80 WOR-3                       1
